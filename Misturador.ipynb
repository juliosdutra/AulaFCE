# %% [markdown]
# <a href="https://colab.research.google.com/github/juliosdutra/AulaFCE/blob/main/Misturador.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from dataclasses import dataclass

@dataclass
class Corrente:
  """
  Representa uma corrente de entrada no misturador.

  Atributos:
      F (float): Vazão mássica da corrente (kg/h).
      X (float): Concentração de sal na corrente (fração mássica).
  """
  Vazao: float
  Concentracao: float

def misturador_calculo(c1: Corrente, c2: Corrente):
  """
  Calcula a vazão e concentração de sal na corrente de saída de um misturador.

    Parâmetros:
        c1 (Corrente): Primeira corrente de entrada.
        c2 (Corrente): Segunda corrente de entrada.

    Retorna:
        tuple: (F_out, X_out)
            F_out (float): Vazão mássica total na saída (kg/h).
            X_out (float): Concentração de sal na saída (fração mássica).
  """
  VazaoFinal = c1.Vazao + c2.Vazao
  ConcFinal  = (c1.Vazao * c1.Concentracao + c2.Vazao * c2.Concentracao)/VazaoFinal
  return VazaoFinal, ConcFinal
