# %% [markdown]
# <a href="https://colab.research.google.com/github/juliosdutra/AulaFCE/blob/main/func_basicas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def soma(a,b):
  '''
  Esta função executa a adição de a e b.
  '''
  return a+b

def subtrai(a,b):
  return a-b
